# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('Datasets/movie_metadata.csv')

# %%
df.head().T
# Out:
#                                                                            0  \
# color                                                                  Color
# director_name                                                  James Cameron
# num_critic_for_reviews                                                   723
# duration                                                                 178
# director_facebook_likes                                                    0
# actor_3_facebook_likes                                                   855
# actor_2_name                                                Joel David Moore
# actor_1_facebook_likes                                                  1000
# gross                                                            7.60506e+08
# genres                                       Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                     CCH Pounder
# ...

# %% [markdown]
# Parejas de actores/directores que generan mejor ránking de Imdb.
# Películas que fracasaron en cuanto a lo $ (Budget - gross).
# Películas mejor rankeadas con más bajo presupuesto

# %% [markdown]
# # Películas mejor rankeadas con más bajo presupuesto

# %%
dt = df[df.columns[1:]]


corr = dt.corr() 

bool_upper_matrix = np.tril(np.ones(corr.shape)).astype(np.bool)
corr = corr.where(bool_upper_matrix)


sns.heatmap(corr, cmap=sns.diverging_palette(120, 10, as_cmap=True),
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values);

# %%
sns.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d984b3a3c978> in <module>()
# ----> 1 sns.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)
#
# NameError: name 'kwargs' is not defined

# %%
# Out:
# Object `df.sortby` not found.
