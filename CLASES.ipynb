# %% [markdown]
# # CLASE 1

# %% [markdown]
# **Importo las librerias**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# matplotlib es la libreria para graficar

# %% [markdown]
# % permite insertar graficos**

# %% [markdown]
# **Importo el dataset**

# %%
ds = pd.read_csv('marathon_results_2017.csv')

# %% [markdown]
# **Head te muestra las primeras 5 filas del archivo para ver si esta bien importado**

# %%
ds.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9   ...         25K      30K      35K      40K     Pace  \
# 0     NaN        NaN   ...     1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN   ...     1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN   ...     1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3     NaN        NaN   ...     1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4     NaN        NaN   ...     1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %% [markdown]
# **Para revisar las columnas del archivo ds.columns**

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %% [markdown]
# **Corrijo las columnas que quiero usar, borro las que no me sirven**

# %%
colnames = ['Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
       'Citizen', '5K', '10K', '15K', '20K', 'Half', '25K',
       '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
       'Gender', 'Division']

# %% [markdown]
# **Reescribo el archivo con las columnas que quiero usar**

# %%
ds = pd.read_csv('marathon_results_2017.csv', usecols = colnames)

# %% [markdown]
# **Reviso que las columnas que seleccione están correctas**

# %%
ds.head()
# Out:
#   Bib              Name  Age M/F           City State Country Citizen  \
# 0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN
# 1  17       Rupp, Galen   30   M       Portland    OR     USA     NaN
# 2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN
# 3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN
# 4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN
#
#         5K      10K   ...         25K      30K      35K      40K     Pace  \
# 0  0:15:25  0:30:28   ...     1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1  0:15:24  0:30:27   ...     1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2  0:15:25  0:30:29   ...     1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3  0:15:25  0:30:29   ...     1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4  0:15:25  0:30:28   ...     1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %% [markdown]
# ** Para poder ver todas las columbas como filas - "trasponer" (para ver que estén todas correctas cuando no entran en la pantalla ingreso ds.head().T**

# %%
ds.head().T
# Out:
#                              0            1              2                 3  \
# Bib                         11           17             23                21
# Name           Kirui, Geoffrey  Rupp, Galen  Osako, Suguru  Biwott, Shadrack
# Age                         24           30             25                32
# M/F                          M            M              M                 M
# City                  Keringet     Portland   Machida-City     Mammoth Lakes
# State                      NaN           OR            NaN                CA
# Country                    KEN          USA            JPN               USA
# Citizen                    NaN          NaN            NaN               NaN
# 5K                     0:15:25      0:15:24        0:15:25           0:15:25
# 10K                    0:30:28      0:30:27        0:30:29           0:30:29
# 15K                    0:45:44      0:45:44        0:45:44           0:45:44
# ...

# %% [markdown]
# **Para ver el tipo de dato uso dtypes**

# %%
ds.dtypes
# Out:
# Bib              object
# Name             object
# Age               int64
# M/F              object
# City             object
# State            object
# Country          object
# Citizen          object
# 5K               object
# 10K              object
# 15K              object
# 20K              object
# Half             object
# 25K              object
# 30K              object
# 35K              object
# 40K              object
# Pace             object
# Proj Time        object
# Official Time    object
# Overall           int64
# Gender            int64
# Division          int64
# dtype: object

# %% [markdown]
# **Para transformar los datos uso ds.iloc - ":" son todas las filas - 8:20 son desde hasta que columnas quiero modificar**

# %%
ds.iloc[:, 8:20] = ds.iloc [:, 8:20].apply(pd.to_timedelta)

# %%
ds.dtypes
# Out:
# Bib                       object
# Name                      object
# Age                        int64
# M/F                       object
# City                      object
# State                     object
# Country                   object
# Citizen                   object
# 5K               timedelta64[ns]
# 10K              timedelta64[ns]
# 15K              timedelta64[ns]
# 20K              timedelta64[ns]
# Half             timedelta64[ns]
# 25K              timedelta64[ns]
# 30K              timedelta64[ns]
# 35K              timedelta64[ns]
# 40K              timedelta64[ns]
# Pace             timedelta64[ns]
# Proj Time        timedelta64[ns]
# Official Time    timedelta64[ns]
# Overall                    int64
# Gender                     int64
# Division                   int64
# dtype: object

# %%
ds.head()
# Out:
#   Bib              Name  Age M/F           City State Country Citizen  \
# 0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN
# 1  17       Rupp, Galen   30   M       Portland    OR     USA     NaN
# 2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN
# 3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN
# 4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN
#
#         5K      10K   ...         25K      30K      35K      40K     Pace  \
# 0 00:15:25 00:30:28   ...    01:16:59 01:33:01 01:48:19 02:02:53 00:04:57
# 1 00:15:24 00:30:27   ...    01:16:59 01:33:01 01:48:19 02:03:14 00:04:58
# 2 00:15:25 00:30:29   ...    01:17:00 01:33:01 01:48:31 02:03:38 00:04:59
# 3 00:15:25 00:30:29   ...    01:17:00 01:33:01 01:48:58 02:04:35 00:05:03
# 4 00:15:25 00:30:28   ...    01:16:59 01:33:01 01:48:41 02:05:00 00:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %% [markdown]
# **Para encontrar datos "null" ds.isnull()**

# %%
ds.isnull()
# Out:
#          Bib   Name    Age    M/F   City  State  Country  Citizen     5K  \
# 0      False  False  False  False  False   True    False     True  False
# 1      False  False  False  False  False  False    False     True  False
# 2      False  False  False  False  False   True    False     True  False
# 3      False  False  False  False  False  False    False     True  False
# 4      False  False  False  False  False   True    False     True  False
# 5      False  False  False  False  False  False    False     True  False
# 6      False  False  False  False  False  False    False     True  False
# 7      False  False  False  False  False   True    False     True  False
# 8      False  False  False  False  False  False    False     True  False
# 9      False  False  False  False  False  False    False     True  False
# 10     False  False  False  False  False  False    False     True  False
# 11     False  False  False  False  False   True    False     True  False
# ...

# %% [markdown]
# **Para hacer un recuento agrego .sum()**

# %%
ds.isnull().sum()
# Out:
# Bib                  0
# Name                 0
# Age                  0
# M/F                  0
# City                 0
# State             3595
# Country              0
# Citizen          25156
# 5K                   0
# 10K                  0
# 15K                  0
# 20K                  0
# Half                 0
# 25K                  0
# 30K                  0
# 35K                  0
# 40K                  0
# Pace                 0
# Proj Time            0
# Official Time        0
# Overall              0
# Gender               0
# Division             0
# dtype: int64

# %% [markdown]
# **Para ver el universo uso .shape**

# %%
ds.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-17af5ffdbfb5> in <module>()
# ----> 1 ds.shape
#
# NameError: name 'ds' is not defined

# %%
ds['Citizen'].value_counts()
# Out:
# GBR    141
# CAN    131
# JPN    115
# CHN     78
# USA     74
# IRL     72
# MEX     69
# FRA     50
# GER     46
# AUS     35
# ESP     27
# NED     25
# VEN     20
# IND     19
# POL     17
# NZL     17
# ITA     15
# ARG     15
# BRA     13
# KOR     13
# PHI     13
# RSA     13
# COL     12
# BEL     12
# SUI     10
# DOM     10
# CRC     10
# DEN     10
# SWE     10
# CZE      9
#       ...
# MAR      2
# GUY      2
# LTU      2
# INA      2
# SLO      2
# PAK      2
# EST      2
# PER      2
# CAM      1
# SRI      1
# BIH      1
# EGY      1
# TUN      1
# LIB      1
# LAT      1
# ALB      1
# ETH      1
# CUB      1
# KEN      1
# BLR      1
# HON      1
# MOZ      1
# ZIM      1
# BAN      1
# JAM      1
# NAM      1
# AZE      1
# ZAM      1
# SRB      1
# CAF      1
# Name: Citizen, Length: 85, dtype: int64

# %% [markdown]
# # Clase 2 - 16 OCTUBRE

# %% [markdown]
# **Citizen - 20K - Division**

# %%
dt = ds.columns[1:]

corr = ds.corr() #returns a dataframe, so it can be reused

# Quitamos el triangulo superior para facilitar la lectura
bool_upper_matrix = np.tril(np.ones(corr.shape)).astype(np.bool)
corr = corr.where(bool_upper_matrix)

# Utilizamos el heatmap de seaborn para visualizar
sns.heatmap(corr, cmap=sns.diverging_palette(120, 10, as_cmap=True),
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values);

# %%
ds.corr()
# Out:
#                Age   Overall    Gender  Division
# Age       1.000000  0.259626  0.368879 -0.579735
# Overall   0.259626  1.000000  0.902077  0.449812
# Gender    0.368879  0.902077  1.000000  0.403068
# Division -0.579735  0.449812  0.403068  1.000000

# %% [markdown]
# # CLASE 3  - 18 OCTUBRE

# %%
import fuzzywuzzy
from fuzzywuzzy import process
import chardet
